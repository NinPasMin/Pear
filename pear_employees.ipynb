# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
pear = pd.read_csv('pear_employees.csv', skipinitialspace = True)
pear.head()
# Out:
#    Unnamed: 0  emp_no        emp_name gender dept_no    dept_name  \
# 0           0   10001  Georgi Facello      M    D005  Development
# 1           1   10001  Georgi Facello      M    D005  Development
# 2           2   10001  Georgi Facello      M    D005  Development
# 3           3   10001  Georgi Facello      M    D005  Development
# 4           4   10001  Georgi Facello      M    D005  Development
#
#   emp_from_date emp_to_date  birth_date  age_hired salary_from_date  \
# 0    1986-06-26  2099-01-01  1953-09-02         32       1986-06-26
# 1    1986-06-26  2099-01-01  1953-09-02         32       1987-06-26
# 2    1986-06-26  2099-01-01  1953-09-02         32       1988-06-25
# 3    1986-06-26  2099-01-01  1953-09-02         32       1989-06-25
# 4    1986-06-26  2099-01-01  1953-09-02         32       1990-06-25
#
#   salary_to_date  salary  previous_salary  salary_increase_pct  \
# 0     1987-06-26   60117              NaN                  NaN
# ...

# %%
pear.isna().sum()
# Out:
# Unnamed: 0              0
# emp_no                  0
# emp_name                0
# gender                  0
# dept_no                 0
# dept_name               0
# emp_from_date           0
# emp_to_date             0
# birth_date              0
# age_hired               0
# salary_from_date        0
# salary_to_date          0
# salary                  0
# previous_salary        42
# salary_increase_pct    42
# title                   0
# title_from_date         0
# title_to_date           0
# manager_no              0
# emp_status              0
# current_date            0
# years_experience        0
# dtype: int64

# %%
gender_null = pear[pear['gender'].isna()]

# %%
list(gender_null['emp_name'].unique())
# Out:
# []

# %%
gender_dict = {'Georgi Facello':'M',
 'Bezalel Simmel':'M',
 'Parto Bamford':'M',
 'Chirstian Koblick':'M',
 'Kyoichi Maliniak':'M',
 'Anneke Preusig':'F',
 'Tzvetan Zielinski':'M',
 'Sumant Peac':'M',
 'Duangkaew Piveteau':'M',
 'Eberhardt Terkki':'M',
 'Berni Genin':'M',
 'Guoxiang Nooteboom':'F',
 'Kazuhide Peha':'F',
 'Ramzi Erde':'M',
 'Bojan Montemayor':'M',
 'Prasadram Heyers':'M',
 'Divier Reistad':'M',
 'Otmar Herbst':'M',
 'Arif Merlo':'M',
 'Bader Swan':'M',
 'Alain Chappelet':'M',
 'Huan Lortz':'M',
 'Alejandro Brender':'M'}

# %%
pear['gender'] = pear['gender'].fillna(pear['emp_name'].map(gender_dict))

# %%
pear.head(2)
# Out:
#    Unnamed: 0  emp_no        emp_name gender dept_no    dept_name  \
# 0           0   10001  Georgi Facello      M    D005  Development
# 1           1   10001  Georgi Facello      M    D005  Development
#
#   emp_from_date emp_to_date  birth_date  age_hired salary_from_date  \
# 0    1986-06-26  2099-01-01  1953-09-02         32       1986-06-26
# 1    1986-06-26  2099-01-01  1953-09-02         32       1987-06-26
#
#   salary_to_date  salary  previous_salary  salary_increase_pct  \
# 0     1987-06-26   60117              NaN                  NaN
# 1     1988-06-25   62102          60117.0                  3.3
#
#              title title_from_date title_to_date  manager_no emp_status  \
# 0  Senior Engineer      1986-06-26    2099-01-01      110022     Active
# 1  Senior Engineer      1986-06-26    2099-01-01      110022     Active
#
#   current_date  years_experience
# 0   2002-09-30              16.3
# 1   2002-09-30              16.3

# %%
pear['gender'].isna().sum()
# Out:
# 0

# %%
pear.query("emp_name == 'Guoxiang Nooteboom' or emp_name == 'Alejandro Brender' ").head()
# Out:
#      Unnamed: 0  emp_no            emp_name gender dept_no        dept_name  \
# 250         250   10015  Guoxiang Nooteboom      F    D008         Research
# 636         636   10039   Alejandro Brender      M    D003  Human Resources
# 637         651   10039   Alejandro Brender      M    D003  Human Resources
# 638         637   10039   Alejandro Brender      M    D003  Human Resources
# 639         652   10039   Alejandro Brender      M    D003  Human Resources
#
#     emp_from_date emp_to_date  birth_date  age_hired salary_from_date  \
# 250    1992-09-19  1993-08-22  1959-08-19         33       1992-09-19
# 636    1988-01-19  2099-01-01  1959-10-01         28       1988-01-19
# 637    1988-01-19  2099-01-01  1959-10-01         28       1988-01-19
# 638    1988-01-19  2099-01-01  1959-10-01         28       1989-01-18
# 639    1988-01-19  2099-01-01  1959-10-01         28       1989-01-18
#
#     salary_to_date  salary  previous_salary  salary_increase_pct  \
# ...

# %%
pear['emp_to_date'].unique()
# Out:
# array(['2099-01-01', '2000-07-31', '2000-06-26', '1996-11-09',
#        '1993-08-22', '1992-07-29', '2002-07-15', '1997-10-15',
#        '1998-04-06', '1999-07-08', '1993-03-24', '1999-10-31',
#        '2002-01-22'], dtype=object)

# %%
pear['emp_to_date'] = pear['emp_to_date'].replace('9999-01-01', '2099-01-01')

# %%
pear['emp_to_date'] = pd.to_datetime(pear['emp_to_date'], format = '%Y-%m-%d', yearfirst = True)

# %%
pear['title_to_date'] = pear['title_to_date'].replace('9999-01-01', '2099-01-01')

# %%
pear['title_to_date'] = pd.to_datetime(pear['title_to_date'], format = '%Y-%m-%d', yearfirst = True)

# %%
pear['salary_to_date'] = pear['salary_to_date'].replace('9999-01-01', '2099-01-01')

# %%
pear['salary_to_date'] = pd.to_datetime(pear['salary_to_date'], format = '%Y-%m-%d', yearfirst = True)

# %%
pear['birth_date'] = pd.to_datetime(pear['birth_date'], format = '%Y-%m-%d', yearfirst = True)

# %%
pear['emp_from_date'] = pd.to_datetime(pear['emp_from_date'], format = '%Y-%m-%d', yearfirst = True)

# %%
pear['salary_from_date'] = pd.to_datetime(pear['salary_from_date'], format = '%Y-%m-%d', yearfirst = True)

# %%
pear['title_from_date'] = pd.to_datetime(pear['title_from_date'], format = '%Y-%m-%d', yearfirst = True)

# %%
pear.info(memory_usage = 'deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 776 entries, 0 to 775
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           776 non-null    int64
#  1   emp_no               776 non-null    int64
#  2   emp_name             776 non-null    object
#  3   gender               776 non-null    object
#  4   dept_no              776 non-null    object
#  5   dept_name            776 non-null    object
#  6   emp_from_date        776 non-null    datetime64[ns]
#  7   emp_to_date          776 non-null    datetime64[ns]
#  8   birth_date           776 non-null    datetime64[ns]
#  9   age_hired            776 non-null    int64
#  10  salary_from_date     776 non-null    datetime64[ns]
#  11  salary_to_date       776 non-null    datetime64[ns]
#  12  salary               776 non-null    int64
#  13  previous_salary      734 non-null    float64
# ...

# %%
pear['age_while_hired_days'] = (pear['emp_from_date'] - pear['birth_date']).dt.days.astype('Int16')
pear.head()
# Out:
#    Unnamed: 0  emp_no        emp_name gender dept_no    dept_name  \
# 0           0   10001  Georgi Facello      M    D005  Development
# 1           1   10001  Georgi Facello      M    D005  Development
# 2           2   10001  Georgi Facello      M    D005  Development
# 3           3   10001  Georgi Facello      M    D005  Development
# 4           4   10001  Georgi Facello      M    D005  Development
#
#   emp_from_date emp_to_date birth_date  age_hired salary_from_date  \
# 0    1986-06-26  2099-01-01 1953-09-02         32       1986-06-26
# 1    1986-06-26  2099-01-01 1953-09-02         32       1987-06-26
# 2    1986-06-26  2099-01-01 1953-09-02         32       1988-06-25
# 3    1986-06-26  2099-01-01 1953-09-02         32       1989-06-25
# 4    1986-06-26  2099-01-01 1953-09-02         32       1990-06-25
#
#   salary_to_date  salary  previous_salary  salary_increase_pct  \
# 0     1987-06-26   60117              NaN                  NaN
# ...

# %%
pear['age_while_hired_years'] = np.floor(pear['age_while_hired_days'] / 365.25).astype('Int16')

# %%
pear.head()
# Out:
#    Unnamed: 0  emp_no        emp_name gender dept_no    dept_name  \
# 0           0   10001  Georgi Facello      M    D005  Development
# 1           1   10001  Georgi Facello      M    D005  Development
# 2           2   10001  Georgi Facello      M    D005  Development
# 3           3   10001  Georgi Facello      M    D005  Development
# 4           4   10001  Georgi Facello      M    D005  Development
#
#   emp_from_date emp_to_date birth_date  age_hired salary_from_date  \
# 0    1986-06-26  2099-01-01 1953-09-02         32       1986-06-26
# 1    1986-06-26  2099-01-01 1953-09-02         32       1987-06-26
# 2    1986-06-26  2099-01-01 1953-09-02         32       1988-06-25
# 3    1986-06-26  2099-01-01 1953-09-02         32       1989-06-25
# 4    1986-06-26  2099-01-01 1953-09-02         32       1990-06-25
#
#   salary_to_date  salary  previous_salary  salary_increase_pct  \
# 0     1987-06-26   60117              NaN                  NaN
# ...

# %%
pear = pear.drop('age_while_hired_days', axis =1)

# %%
pear.head(2)
# Out:
#    Unnamed: 0  emp_no        emp_name gender dept_no    dept_name  \
# 0           0   10001  Georgi Facello      M    D005  Development
# 1           1   10001  Georgi Facello      M    D005  Development
#
#   emp_from_date emp_to_date birth_date  age_hired salary_from_date  \
# 0    1986-06-26  2099-01-01 1953-09-02         32       1986-06-26
# 1    1986-06-26  2099-01-01 1953-09-02         32       1987-06-26
#
#   salary_to_date  salary  previous_salary  salary_increase_pct  \
# 0     1987-06-26   60117              NaN                  NaN
# 1     1988-06-25   62102          60117.0                  3.3
#
#              title title_from_date title_to_date  manager_no emp_status  \
# 0  Senior Engineer      1986-06-26    2099-01-01      110022     Active
# 1  Senior Engineer      1986-06-26    2099-01-01      110022     Active
#
#   current_date  years_experience  age_while_hired_years
# 0   2002-09-30              16.3                     32
# ...

# %%
pear['title'].unique()
# Out:
# array(['Senior Engineer', 'Staff', 'Engineer', 'Senior Staff',
#        'Assistant Engineer', 'Technique Leader', 'Manager'], dtype=object)

# %%
pear['dept_no'].unique()
# Out:
# array(['D005', 'D007', 'D004', 'D003', 'D008', 'D006', 'D009', 'D001'],
#       dtype=object)

# %%
pear['dept_no'] = pear['dept_no'].str.replace('d', 'D')

# %%
pear['dept_no'].unique()
# Out:
# array(['D005', 'D007', 'D004', 'D003', 'D008', 'D006', 'D009', 'D001'],
#       dtype=object)

# %%
pear['dept_name'].unique()
# Out:
# array(['Development', 'Sales', 'Production', 'Human Resources',
#        'Research', 'Quality Management', 'Customer Service', 'Marketing'],
#       dtype=object)

# %%
pear.columns
# Out:
# Index(['Unnamed: 0', 'emp_no', 'emp_name', 'gender', 'dept_no', 'dept_name',
#        'emp_from_date', 'emp_to_date', 'birth_date', 'age_hired',
#        'salary_from_date', 'salary_to_date', 'salary', 'previous_salary',
#        'salary_increase_pct', 'title', 'title_from_date', 'title_to_date',
#        'manager_no', 'emp_status', 'current_date', 'years_experience',
#        'age_while_hired_years'],
#       dtype='object')

# %%
new_column_order = ['emp_no', 'emp_name', 'gender', 'dept_no', 'dept_name', 'emp_from_date', 'emp_to_date',
        'birth_date', 'age_while_hired_years', 'salary',
       'salary_from_date', 'salary_to_date', 'title', 'title_from_date',
       'title_to_date', 'manager_no']

# %%
pear = pear[new_column_order]

# %%
pear.columns
# Out:
# Index(['emp_no', 'emp_name', 'gender', 'dept_no', 'dept_name', 'emp_from_date',
#        'emp_to_date', 'birth_date', 'age_while_hired_years', 'salary',
#        'salary_from_date', 'salary_to_date', 'title', 'title_from_date',
#        'title_to_date', 'manager_no'],
#       dtype='object')

# %%
pear.columns = ['emp_no', 'emp_name', 'gender', 'dept_no', 'dept_name',
       'emp_from_date', 'emp_to_date', 'birth_date', 'age_hired',
       'salary', 'salary_from_date', 'salary_to_date', 'title',
       'title_from_date', 'title_to_date', 'manager_no']

# %%
pear.head(3)
# Out:
#    emp_no        emp_name gender dept_no    dept_name emp_from_date  \
# 0   10001  Georgi Facello      M    D005  Development    1986-06-26
# 1   10001  Georgi Facello      M    D005  Development    1986-06-26
# 2   10001  Georgi Facello      M    D005  Development    1986-06-26
#
#   emp_to_date birth_date  age_hired  salary salary_from_date salary_to_date  \
# 0  2099-01-01 1953-09-02         32   60117       1986-06-26     1987-06-26
# 1  2099-01-01 1953-09-02         32   62102       1987-06-26     1988-06-25
# 2  2099-01-01 1953-09-02         32   66074       1988-06-25     1989-06-25
#
#              title title_from_date title_to_date  manager_no
# 0  Senior Engineer      1986-06-26    2099-01-01      110022
# 1  Senior Engineer      1986-06-26    2099-01-01      110022
# 2  Senior Engineer      1986-06-26    2099-01-01      110022

# %%
pear = pear.sort_values(by=['emp_no', 'salary_from_date'])

# %%
pear['previous_salary'] = pear.groupby('emp_no')['salary'].shift(1)

# %%
pear[['emp_no', 'emp_name', 'salary', 'previous_salary']].iloc[14:21]
# Out:
#     emp_no        emp_name  salary  previous_salary
# 14   10001  Georgi Facello   85112          84917.0
# 15   10001  Georgi Facello   85097          85112.0
# 16   10001  Georgi Facello   88958          85097.0
# 17   10002  Bezalel Simmel   65828              NaN
# 18   10002  Bezalel Simmel   65909          65828.0
# 19   10002  Bezalel Simmel   67534          65909.0
# 20   10002  Bezalel Simmel   69366          67534.0

# %%
pear['salary_increase_pct'] = (((pear['salary'] - pear['previous_salary'])/pear['previous_salary'])*100).round(2)

# %%
pear[['emp_no', 'emp_name', 'salary', 'previous_salary', 'salary_increase_pct']].iloc[14:21]
# Out:
#     emp_no        emp_name  salary  previous_salary  salary_increase_pct
# 14   10001  Georgi Facello   85112          84917.0                 0.23
# 15   10001  Georgi Facello   85097          85112.0                -0.02
# 16   10001  Georgi Facello   88958          85097.0                 4.54
# 17   10002  Bezalel Simmel   65828              NaN                  NaN
# 18   10002  Bezalel Simmel   65909          65828.0                 0.12
# 19   10002  Bezalel Simmel   67534          65909.0                 2.47
# 20   10002  Bezalel Simmel   69366          67534.0                 2.71

# %%
pear.columns
# Out:
# Index(['emp_no', 'emp_name', 'gender', 'dept_no', 'dept_name', 'emp_from_date',
#        'emp_to_date', 'birth_date', 'age_hired', 'salary', 'salary_from_date',
#        'salary_to_date', 'title', 'title_from_date', 'title_to_date',
#        'manager_no', 'previous_salary', 'salary_increase_pct'],
#       dtype='object')

# %%
pear = pear.loc[:,['emp_no', 'emp_name', 'gender', 'dept_no', 'dept_name', 'emp_from_date',
       'emp_to_date', 'birth_date', 'age_hired', 'salary_from_date',
       'salary_to_date', 'salary', 'previous_salary', 'salary_increase_pct', 'title', 'title_from_date', 'title_to_date',
       'manager_no']]

# %%
(pear
 .groupby(['title'])
 .agg({'salary': ['max','min','mean']})).round(2)
# Out:
#                     salary
#                        max    min      mean
# title
# Assistant Engineer   96646  46671  77304.12
# Engineer             94443  39520  61381.42
# Manager             108407  69941  88371.69
# Senior Engineer      94443  39520  61864.30
# Senior Staff        108407  40000  70824.39
# Staff                99651  40000  66288.71
# Technique Leader     84169  40000  60400.18

# %%
pear.head(1)
# Out:
#    emp_no        emp_name gender dept_no    dept_name emp_from_date  \
# 0   10001  Georgi Facello      M    D005  Development    1986-06-26
#
#   emp_to_date birth_date  age_hired salary_from_date salary_to_date  salary  \
# 0  2099-01-01 1953-09-02         32       1986-06-26     1987-06-26   60117
#
#    previous_salary  salary_increase_pct            title title_from_date  \
# 0              NaN                  NaN  Senior Engineer      1986-06-26
#
#   title_to_date  manager_no
# 0    2099-01-01      110022

# %%
pear['emp_status'] = np.where(pear['emp_to_date'] == '2099-01-01', 'Active', 'Left')

# %%
pear.head()
# Out:
#    emp_no        emp_name gender dept_no    dept_name emp_from_date  \
# 0   10001  Georgi Facello      M    D005  Development    1986-06-26
# 1   10001  Georgi Facello      M    D005  Development    1986-06-26
# 2   10001  Georgi Facello      M    D005  Development    1986-06-26
# 3   10001  Georgi Facello      M    D005  Development    1986-06-26
# 4   10001  Georgi Facello      M    D005  Development    1986-06-26
#
#   emp_to_date birth_date  age_hired salary_from_date salary_to_date  salary  \
# 0  2099-01-01 1953-09-02         32       1986-06-26     1987-06-26   60117
# 1  2099-01-01 1953-09-02         32       1987-06-26     1988-06-25   62102
# 2  2099-01-01 1953-09-02         32       1988-06-25     1989-06-25   66074
# 3  2099-01-01 1953-09-02         32       1989-06-25     1990-06-25   66596
# 4  2099-01-01 1953-09-02         32       1990-06-25     1991-06-25   66961
#
#    previous_salary  salary_increase_pct            title title_from_date  \
# ...

# %%
pear['current_date'] = pd.to_datetime('2002-09-30')

# %%
pear.head(2)
# Out:
#    emp_no        emp_name gender dept_no    dept_name emp_from_date  \
# 0   10001  Georgi Facello      M    D005  Development    1986-06-26
# 1   10001  Georgi Facello      M    D005  Development    1986-06-26
#
#   emp_to_date birth_date  age_hired salary_from_date salary_to_date  salary  \
# 0  2099-01-01 1953-09-02         32       1986-06-26     1987-06-26   60117
# 1  2099-01-01 1953-09-02         32       1987-06-26     1988-06-25   62102
#
#    previous_salary  salary_increase_pct            title title_from_date  \
# 0              NaN                  NaN  Senior Engineer      1986-06-26
# 1          60117.0                  3.3  Senior Engineer      1986-06-26
#
#   title_to_date  manager_no emp_status current_date
# 0    2099-01-01      110022     Active   2002-09-30
# 1    2099-01-01      110022     Active   2002-09-30

# %%
pear['years_experience'] = ((np.where(pear['emp_status'] == 'Active', 
                                      pd.to_timedelta(pear['current_date'] - pear['emp_from_date']).dt.days, 0))/365.5).round(1)

# %%
pear.head()
# Out:
#    emp_no        emp_name gender dept_no    dept_name emp_from_date  \
# 0   10001  Georgi Facello      M    D005  Development    1986-06-26
# 1   10001  Georgi Facello      M    D005  Development    1986-06-26
# 2   10001  Georgi Facello      M    D005  Development    1986-06-26
# 3   10001  Georgi Facello      M    D005  Development    1986-06-26
# 4   10001  Georgi Facello      M    D005  Development    1986-06-26
#
#   emp_to_date birth_date  age_hired salary_from_date salary_to_date  salary  \
# 0  2099-01-01 1953-09-02         32       1986-06-26     1987-06-26   60117
# 1  2099-01-01 1953-09-02         32       1987-06-26     1988-06-25   62102
# 2  2099-01-01 1953-09-02         32       1988-06-25     1989-06-25   66074
# 3  2099-01-01 1953-09-02         32       1989-06-25     1990-06-25   66596
# 4  2099-01-01 1953-09-02         32       1990-06-25     1991-06-25   66961
#
#    previous_salary  salary_increase_pct            title title_from_date  \
# ...

# %%
pear.head()
# Out:
#    emp_no        emp_name gender dept_no    dept_name emp_from_date  \
# 0   10001  Georgi Facello      M    D005  Development    1986-06-26
# 1   10001  Georgi Facello      M    D005  Development    1986-06-26
# 2   10001  Georgi Facello      M    D005  Development    1986-06-26
# 3   10001  Georgi Facello      M    D005  Development    1986-06-26
# 4   10001  Georgi Facello      M    D005  Development    1986-06-26
#
#   emp_to_date birth_date  age_hired salary_from_date salary_to_date  salary  \
# 0  2099-01-01 1953-09-02         32       1986-06-26     1987-06-26   60117
# 1  2099-01-01 1953-09-02         32       1987-06-26     1988-06-25   62102
# 2  2099-01-01 1953-09-02         32       1988-06-25     1989-06-25   66074
# 3  2099-01-01 1953-09-02         32       1989-06-25     1990-06-25   66596
# 4  2099-01-01 1953-09-02         32       1990-06-25     1991-06-25   66961
#
#    previous_salary  salary_increase_pct            title title_from_date  \
# ...

# %%
pear.to_csv('pear_employees.csv')

# %%
pear.to_excel('pear_employees.xlsx')
